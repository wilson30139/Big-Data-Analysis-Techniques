# %%
"""
# !pip install twstock 
# !pip install yahoo_fin
"""

from twstock import Stock
from yahoo_fin.stock_info import *

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.font_manager as fm
import numpy as np
from matplotlib import font_manager

import seaborn as sns
from matplotlib.pyplot import figure



plt.rcParams['font.family'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False

# %%
dataList = pd.read_csv('./台積電股票2020資料.csv')
dataList
# Out:
#            Date   Open   High    Low  Close  Change  Change%  \
# 0    2020/12/31  526.0  530.0  524.0  530.0     5.0     0.95
# 1    2020/12/30  516.0  525.0  514.0  525.0    10.0     1.94
# 2    2020/12/29  515.0  517.0  513.0  515.0     0.0     0.00
# 3    2020/12/28  512.0  515.0  509.0  515.0     4.0     0.78
# 4    2020/12/25  514.0  515.0  510.0  511.0     1.0     0.20
# ..          ...    ...    ...    ...    ...     ...      ...
# 240  2020/01/08  325.0  333.0  325.0  329.5     0.0     0.00
# 241  2020/01/07  332.5  333.0  326.5  329.5    -2.5    -0.75
# 242  2020/01/06  333.0  334.5  332.0  332.0    -7.5    -2.21
# 243  2020/01/03  344.0  345.0  335.5  339.5     0.5     0.15
# 244  2020/01/02  332.5  339.0  332.5  339.0     8.0     2.42
#
#      Volume('000 shares)
# 0              31173.332
# 1              46705.107
# 2              20226.736
# 3              19520.886
# 4              12581.145
# ..                   ...
# 240            37913.748
# ...

# %%
stock_no = '2330.TW'

data = get_data(stock_no , start_date = '2018/01/01')
data.head()
# Out:
#              open   high    low  close    adjclose    volume   ticker
# 2018-01-02  231.5  232.5  231.0  232.5  204.426163  18055269  2330.TW
# 2018-01-03  236.0  238.0  235.5  237.0  208.382782  29308091  2330.TW
# 2018-01-04  240.0  240.0  236.5  239.5  210.580902  29096613  2330.TW
# 2018-01-05  240.0  240.0  238.0  240.0  211.020523  22438255  2330.TW
# 2018-01-08  242.0  242.5  240.5  242.0  212.779068  20233692  2330.TW

# %%
d2 = {'Date': data.index,
        'Close': data['close']
        }

newDf = pd.DataFrame(d2)
newDf
# Out:
#                  Date  Close
# 2016-02-01 2016-02-01  144.0
# 2016-02-02 2016-02-02  142.5
# 2016-02-03 2016-02-03  146.0
# 2016-02-15 2016-02-15  145.0
# 2016-02-16 2016-02-16  147.5
# ...               ...    ...
# 2021-12-21 2021-12-21  597.0
# 2021-12-22 2021-12-22  600.0
# 2021-12-23 2021-12-23  606.0
# 2021-12-24 2021-12-24  604.0
# 2021-12-27 2021-12-27  606.0
#
# [1442 rows x 2 columns]

# %%
"""
CSV
"""
dataList['Date'] = pd.to_datetime(dataList['Date'])
fig, ax = plt.subplots(figsize=(4,3),dpi=200)

plt.plot(dataList["Date"], dataList["Close"], color = "r", label = "台積電")
months = mdates.MonthLocator(interval=1, bymonthday=-1)
months_fmt = mdates.DateFormatter('%Y年-%m月')
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(months_fmt)
ax.legend(loc='upper right', ncol=2, fontsize=6)

ax.tick_params(axis='x', which='major', labelrotation=45)
plt.xticks(fontsize=6)
# Out:
# (array([18261., 18292., 18321., 18352., 18382., 18413., 18443., 18474.,
#         18505., 18535., 18566., 18596., 18627.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
"""
Yahoo API
"""
newDf['Date'] = pd.to_datetime(newDf['Date'])
fig, ax = plt.subplots(figsize=(4,3),dpi=150)
plt.plot(newDf["Date"], newDf["Close"], color = "b", label = "台積電(from Yahoo Stock API)")
months = mdates.MonthLocator(interval=1, bymonthday=-1)
months_fmt = mdates.DateFormatter('%Y年-%m月')
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(months_fmt)
ax.legend(loc='upper right', ncol=2, fontsize=6)
ax.tick_params(axis='x', which='major', labelrotation=45)
plt.xticks(fontsize=6)


plt.show()

# %%
# !python -c "print (__import__('matplotlib').matplotlib_fname())"
font_set = {f.name for f in font_manager.fontManager.ttflist}
for f in font_set:
    print(f)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# Nirmala UI
# DejaVu Serif Display
# Microsoft PhagsPa
# Imprint MT Shadow
# Ink Free
# Calibri
# Comic Sans MS
# Franklin Gothic Medium
# Calisto MT
# Poor Richard
# Cooper Black
# Consolas
# Haettenschweiler
# Parchment
# Lucida Console
# Tera Special
# Mistral
# Leelawadee UI
# Broadway
# Century
# Centaur
# Footlight MT Light
# Gill Sans MT Ext Condensed Bold
# Gigi
# Gill Sans MT
# Maiandra GD
# Bookman Old Style
# Constantia
# Georgia
# Niagara Engraved
# Bradley Hand ITC
# Matura MT Script Capitals
# Viner Hand ITC
# Gill Sans Ultra Bold Condensed
# SimSun-ExtB
# Dealerplate
# Times New Roman
# Pristina
# Old English Text MT
# Microsoft Yi Baiti
# Segoe UI Historic
# Rage Italic
# Showcard Gothic
# Agency FB
# Gill Sans MT Condensed
# Playbill
# OCR A Extended
# Gloucester MT Extra Condensed
# Segoe Print
# Copperplate Gothic Bold
# Stencil
# Vivaldi
# Magneto
# Script MT Bold
# Malgun Gothic
# ...

# %%
"""
CSV
"""
df=pd.DataFrame(dataList["Close"].values,
                index=dataList["Date"],
                columns=['A'])

df.reset_index(inplace=True)
df.columns = ['Date','收市價']
df.head()

df['年月'] = df['Date'].dt.strftime('%Y年-%m月')
fig, ax = plt.subplots()
fig.set_size_inches((12,4))
sns.boxplot(x='年月',y='收市價',data=df,ax=ax)
ax.tick_params(axis='x', which='major', labelrotation=45)

# %%
import numpy as np
import seaborn as sns
from matplotlib.pyplot import figure

"""
Yahoo API
"""


df=pd.DataFrame(newDf["Close"].values,
                index=newDf["Date"],
                columns=['A'])

df.reset_index(inplace=True)
df.columns = ['Date','收市價']
df.head()

df['年月'] = df['Date'].dt.strftime('%Y年-%m月')
fig, ax = plt.subplots()
fig.set_size_inches((12,4))
sns.boxplot(x='年月',y='收市價',data=df,ax=ax)
ax.tick_params(axis='x', which='major', labelrotation=45)


fig.set_dpi(300)

plt.show()

# %%
df
# Out:
#            Date    收市價         年月
# 0    2015-02-02  142.5  2015年-02月
# 1    2015-02-03  144.5  2015年-02月
# 2    2015-02-04  146.0  2015年-02月
# 3    2015-02-05  145.5  2015年-02月
# 4    2015-02-06  143.0  2015年-02月
# ...         ...    ...        ...
# 1684 2021-12-21  597.0  2021年-12月
# 1685 2021-12-22  600.0  2021年-12月
# 1686 2021-12-23  606.0  2021年-12月
# 1687 2021-12-24  604.0  2021年-12月
# 1688 2021-12-27  606.0  2021年-12月
#
# [1689 rows x 3 columns]

# %%
dataList["Close"].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7b2a3316e858> in <module>
# ----> 1 dataList["Close"].values
#
# NameError: name 'dataList' is not defined

# %%
type(np.random.randint(50,1000,365).reshape(-1,1))
# Out:
# numpy.ndarray

# %%
stock_no = '2330'
stock = Stock(stock_no)
data = stock.fetch_from(2021,1)

df = pd.DataFrame(data)
df.head()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# TimeoutError: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。
#
# ...

# %%
df
# Out:
#            Date    收市價         年月
# 0    2015-02-02  142.5  2015年-02月
# 1    2015-02-03  144.5  2015年-02月
# 2    2015-02-04  146.0  2015年-02月
# 3    2015-02-05  145.5  2015年-02月
# 4    2015-02-06  143.0  2015年-02月
# ...         ...    ...        ...
# 1684 2021-12-21  597.0  2021年-12月
# 1685 2021-12-22  600.0  2021年-12月
# 1686 2021-12-23  606.0  2021年-12月
# 1687 2021-12-24  604.0  2021年-12月
# 1688 2021-12-27  606.0  2021年-12月
#
# [1689 rows x 3 columns]

# %%
from yahoo_fin.stock_info import *

stock_no = '2330.TW'

data = get_data(stock_no , start_date = '2021/01/01')
data.head()
data['close']

type(data['close'])
# Out:
# pandas.core.series.Series

# %%
newDf
# Out:
#                  Date  Close
# 2015-02-02 2015-02-02  142.5
# 2015-02-03 2015-02-03  144.5
# 2015-02-04 2015-02-04  146.0
# 2015-02-05 2015-02-05  145.5
# 2015-02-06 2015-02-06  143.0
# ...               ...    ...
# 2021-12-21 2021-12-21  597.0
# 2021-12-22 2021-12-22  600.0
# 2021-12-23 2021-12-23  606.0
# 2021-12-24 2021-12-24  604.0
# 2021-12-27 2021-12-27  606.0
#
# [1689 rows x 2 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
data.shape
# Out:
# (971, 7)

# %%
data = data['open'].values
data = data.reshape(-1, 1)

# %%
dataset_train = np.array(data[:int(data.shape[0]*0.8)])
dataset_test = np.array(data[int(data.shape[0]*0.8):])

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset_train = scaler.fit_transform(dataset_train)
dataset_test = scaler.transform(dataset_test)

# %%
def create_dataset(df):
    x = []
    y = []
    for i in range(50, df.shape[0]):
        x.append(df[i-50:i, 0])
        y.append(df[i, 0])
    x = np.array(x)
    y = np.array(y)
    return x,y

# %%
x_train, y_train = create_dataset(dataset_train)
x_test, y_test = create_dataset(dataset_test)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
from tensorflow import keras 

from tensorflow.keras.models import Sequential

model = Sequential()
model.add(LSTM(units=96, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=96,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=96,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=96))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(x_train, y_train, epochs=50, batch_size=32)
model.save('stock_prediction.h5')
# Out:
# Epoch 1/50
# 23/23 [==============================] - 1s 65ms/step - loss: 0.0145
# Epoch 2/50
# 23/23 [==============================] - 1s 64ms/step - loss: 0.0035
# Epoch 3/50
# 23/23 [==============================] - 1s 64ms/step - loss: 0.0027
# Epoch 4/50
# 23/23 [==============================] - 1s 63ms/step - loss: 0.0029
# Epoch 5/50
# 23/23 [==============================] - 1s 59ms/step - loss: 0.0027
# Epoch 6/50
# 23/23 [==============================] - 1s 60ms/step - loss: 0.0033
# Epoch 7/50
# 23/23 [==============================] - 1s 59ms/step - loss: 0.0026
# Epoch 8/50
# 23/23 [==============================] - 1s 58ms/step - loss: 0.0023
# Epoch 9/50
# 23/23 [==============================] - 1s 59ms/step - loss: 0.0018
# Epoch 10/50
# 23/23 [==============================] - 1s 60ms/step - loss: 0.0022
# Epoch 11/50
# 23/23 [==============================] - 1s 59ms/step - loss: 0.0019
# Epoch 12/50
# ...

# %%
model = load_model('stock_prediction.h5')

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))

fig, ax = plt.subplots(figsize=(16,8))
ax.set_facecolor('#000041')
ax.plot(y_test_scaled, color='red', label='Original price')
plt.plot(predictions, color='cyan', label='Predicted price')
plt.legend()
